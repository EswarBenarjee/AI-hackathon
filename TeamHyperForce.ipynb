# %%
import numpy as np
import pandas as pd  
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn.datasets import load_boston
from sklearn import linear_model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA,TruncatedSVD
boston_dataset = load_boston()

# %%
print(boston_dataset)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
#        15.6, 11.8, 13.8, 15.6, 14.6, 17.8, 15.4, 21.5, 19.6, 15.3, 19.4,
#        17. , 15.6, 13.1, 41.3, 24.3, 23.3, 27. , 50. , 50. , 50. , 22.7,
#        25. , 50. , 23.8, 23.8, 22.3, 17.4, 19.1, 23.1, 23.6, 22.6, 29.4,
#        23.2, 24.6, 29.9, 37.2, 39.8, 36.2, 37.9, 32.5, 26.4, 29.6, 50. ,
#        32. , 29.8, 34.9, 37. , 30.5, 36.4, 31.1, 29.1, 50. , 33.3, 30.3,
#        34.6, 34.9, 32.9, 24.1, 42.3, 48.5, 50. , 22.6, 24.4, 22.5, 24.4,
#        20. , 21.7, 19.3, 22.4, 28.1, 23.7, 25. , 23.3, 28.7, 21.5, 23. ,
#        26.7, 21.7, 27.5, 30.1, 44.8, 50. , 37.6, 31.6, 46.7, 31.5, 24.3,
#        31.7, 41.7, 48.3, 29. , 24. , 25.1, 31.5, 23.7, 23.3, 22. , 20.1,
#        22.2, 23.7, 17.6, 18.5, 24.3, 20.5, 24.5, 26.2, 24.4, 24.8, 29.6,
#        42.8, 21.9, 20.9, 44. , 50. , 36. , 30.1, 33.8, 43.1, 48.8, 31. ,
#        36.5, 22.8, 30.7, 50. , 43.5, 20.7, 21.1, 25.2, 24.4, 35.2, 32.4,
#        32. , 33.2, 33.1, 29.1, 35.1, 45.4, 35.4, 46. , 50. , 32.2, 22. ,
#        20.1, 23.2, 22.3, 24.8, 28.5, 37.3, 27.9, 23.9, 21.7, 28.6, 27.1,
#        20.3, 22.5, 29. , 24.8, 22. , 26.4, 33.1, 36.1, 28.4, 33.4, 28.2,
#        22.8, 20.3, 16.1, 22.1, 19.4, 21.6, 23.8, 16.2, 17.8, 19.8, 23.1,
#        21. , 23.8, 23.1, 20.4, 18.5, 25. , 24.6, 23. , 22.2, 19.3, 22.6,
#        19.8, 17.1, 19.4, 22.2, 20.7, 21.1, 19.5, 18.5, 20.6, 19. , 18.7,
#        32.7, 16.5, 23.9, 31.2, 17.5, 17.2, 23.1, 24.5, 26.6, 22.9, 24.1,
#        18.6, 30.1, 18.2, 20.6, 17.8, 21.7, 22.7, 22.6, 25. , 19.9, 20.8,
#        16.8, 21.9, 27.5, 21.9, 23.1, 50. , 50. , 50. , 50. , 50. , 13.8,
#        13.8, 15. , 13.9, 13.3, 13.1, 10.2, 10.4, 10.9, 11.3, 12.3,  8.8,
#         7.2, 10.5,  7.4, 10.2, 11.5, 15.1, 23.2,  9.7, 13.8, 12.7, 13.1,
#        12.5,  8.5,  5. ,  6.3,  5.6,  7.2, 12.1,  8.3,  8.5,  5. , 11.9,
#        27.9, 17.2, 27.5, 15. , 17.2, 17.9, 16.3,  7. ,  7.2,  7.5, 10.4,
#         8.8,  8.4, 16.7, 14.2, 20.8, 13.4, 11.7,  8.3, 10.2, 10.9, 11. ,
#         9.5, 14.5, 14.1, 16.1, 14.3, 11.7, 13.4,  9.6,  8.7,  8.4, 12.8,
#        10.5, 17.1, 18.4, 15.4, 10.8, 11.8, 14.9, 12.6, 14.1, 13. , 13.4,
#        15.2, 16.1, 17.8, 14.9, 14.1, 12.7, 13.5, 14.9, 20. , 16.4, 17.7,
#        19.5, 20.2, 21.4, 19.9, 19. , 19.1, 19.1, 20.1, 19.9, 19.6, 23.2,
#        29.8, 13.8, 13.3, 16.7, 12. , 14.6, 21.4, 23. , 23.7, 25. , 21.8,
#        20.6, 21.2, 19.1, 20.6, 15.2,  7. ,  8.1, 13.6, 20.1, 21.8, 24.5,
#        23.1, 19.7, 18.3, 21.2, 17.5, 16.8, 22.4, 20.6, 23.9, 22. , 11.9]), 'feature_names': array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7'), 'DESCR': ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,000\n        - PTRATIO  pupil-teacher ratio by town\n        - B        1000(Bk - 0.63)^2 where Bk is the proportion of black people by town\n        - LSTAT    % lower status of the population\n        - MEDV     Median value of owner-occupied homes in $1000's\n\n    :Missing Attribute Values: None\n\n    :Creator: Harrison, D. and Rubinfeld, D.L.\n\nThis is a copy of UCI ML housing dataset.\nhttps://archive.ics.uci.edu/ml/machine-learning-databases/housing/\n\n\nThis dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.\n\nThe Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic\nprices and the demand for clean air', J. Environ. Economics & Management,\nvol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics\n...', Wiley, 1980.   N.B. Various transformations are used in the table on\npages 244-261 of the latter.\n\nThe Boston house-price data has been used in many machine learning papers that address regression\nproblems.   \n     \n.. topic:: References\n\n   - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.\n   - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.\n", 'filename': 'C:\\Users\\eswar\\anaconda3\\lib\\site-packages\\sklearn\\datasets\\data\\boston_house_prices.csv'}

# %%
boston = pd.DataFrame(boston_dataset.data, columns=boston_dataset.feature_names)
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
boston['MEDV'] = boston_dataset.target

# %%
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
X = boston.iloc[:, :-1]
y = boston.iloc[:, -1]
reg=linear_model.LinearRegression()
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

# %%
svd=TruncatedSVD(n_components=2)
X1=svd.fit(X).transform(X)
y_pre2 =reg.predict(X_test)
X1
# Out:
# array([[ 484.44692036, -123.35204687],
#        [ 444.53013893, -155.430283  ],
#        [ 439.66684064, -152.84391875],
#        ...,
#        [ 470.02195591, -135.77172695],
#        [ 467.68131103, -133.12507681],
#        [ 468.79457597, -136.02265463]])

# %%
boston.insert(loc=0, column='ef1', value=X1[:, 0])
boston.insert(loc=1, column='ef2', value=X1[:, 1])

# %%
boston
# Out:
#             ef1         ef2     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE  \
# 0    484.446920 -123.352047  0.00632  18.0   2.31   0.0  0.538  6.575  65.2
# 1    444.530139 -155.430283  0.02731   0.0   7.07   0.0  0.469  6.421  78.9
# 2    439.666841 -152.843919  0.02729   0.0   7.07   0.0  0.469  7.185  61.1
# 3    423.393458 -167.230348  0.03237   0.0   2.18   0.0  0.458  6.998  45.8
# 4    425.911349 -168.725125  0.06905   0.0   2.18   0.0  0.458  7.147  54.2
# ..          ...         ...      ...   ...    ...   ...    ...    ...   ...
# 501  464.326996 -132.511027  0.06263   0.0  11.93   0.0  0.573  6.593  69.1
# 502  468.311141 -136.118632  0.04527   0.0  11.93   0.0  0.573  6.120  76.7
# 503  470.021956 -135.771727  0.06076   0.0  11.93   0.0  0.573  6.976  91.0
# 504  467.681311 -133.125077  0.10959   0.0  11.93   0.0  0.573  6.794  89.3
# 505  468.794576 -136.022655  0.04741   0.0  11.93   0.0  0.573  6.030  80.8
#
#         DIS  RAD    TAX  PTRATIO       B  LSTAT  MEDV
# 0    4.0900  1.0  296.0     15.3  396.90   4.98  24.0
# 1    4.9671  2.0  242.0     17.8  396.90   9.14  21.6
# 2    4.9671  2.0  242.0     17.8  392.83   4.03  34.7
# 3    6.0622  3.0  222.0     18.7  394.63   2.94  33.4
# 4    6.0622  3.0  222.0     18.7  396.90   5.33  36.2
# ..      ...  ...    ...      ...     ...    ...   ...
# 501  2.4786  1.0  273.0     21.0  391.99   9.67  22.4
# 502  2.2875  1.0  273.0     21.0  396.90   9.08  20.6
# 503  2.1675  1.0  273.0     21.0  396.90   5.64  23.9
# 504  2.3889  1.0  273.0     21.0  393.45   6.48  22.0
# 505  2.5050  1.0  273.0     21.0  396.90   7.88  11.9
#
# [506 rows x 16 columns]

# %%
#PCA
x = boston.iloc[:, :-1]
y = boston.iloc[:, -1]
reg=linear_model.LinearRegression()
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)
pca=PCA(0.85,whiten="True")
x_pca=pca.fit(x).transform(x)
print("original",x.shape[1])
print("reduced",x_pca.shape)
print(x_pca)
a = x_pca
a
# Out:
# original 15
# reduced (506, 2)
# [[-0.68159783 -0.07326124]
#  [-0.96052724  0.12070259]
#  [-0.96342707  0.18088816]
#  ...
#  [-0.78671395 -0.00122294]
#  [-0.7817236   0.04152989]
#  [-0.7915552   0.00494403]]
# array([[-0.68159783, -0.07326124],
#        [-0.96052724,  0.12070259],
#        [-0.96342707,  0.18088816],
#        ...,
#        [-0.78671395, -0.00122294],
#        [-0.7817236 ,  0.04152989],
#        [-0.7915552 ,  0.00494403]])

# %%
boston.insert(loc=0, column='ef3', value=X1[:, 0])
boston.insert(loc=1, column='ef4', value=X1[:, 1])

# %%
boston
# Out:
#             ef3         ef4         ef1         ef2     CRIM    ZN  INDUS  \
# 0    484.446920 -123.352047  484.446920 -123.352047  0.00632  18.0   2.31
# 1    444.530139 -155.430283  444.530139 -155.430283  0.02731   0.0   7.07
# 2    439.666841 -152.843919  439.666841 -152.843919  0.02729   0.0   7.07
# 3    423.393458 -167.230348  423.393458 -167.230348  0.03237   0.0   2.18
# 4    425.911349 -168.725125  425.911349 -168.725125  0.06905   0.0   2.18
# ..          ...         ...         ...         ...      ...   ...    ...
# 501  464.326996 -132.511027  464.326996 -132.511027  0.06263   0.0  11.93
# 502  468.311141 -136.118632  468.311141 -136.118632  0.04527   0.0  11.93
# 503  470.021956 -135.771727  470.021956 -135.771727  0.06076   0.0  11.93
# 504  467.681311 -133.125077  467.681311 -133.125077  0.10959   0.0  11.93
# 505  468.794576 -136.022655  468.794576 -136.022655  0.04741   0.0  11.93
#
#      CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO       B  LSTAT  \
# 0     0.0  0.538  6.575  65.2  4.0900  1.0  296.0     15.3  396.90   4.98
# 1     0.0  0.469  6.421  78.9  4.9671  2.0  242.0     17.8  396.90   9.14
# 2     0.0  0.469  7.185  61.1  4.9671  2.0  242.0     17.8  392.83   4.03
# 3     0.0  0.458  6.998  45.8  6.0622  3.0  222.0     18.7  394.63   2.94
# 4     0.0  0.458  7.147  54.2  6.0622  3.0  222.0     18.7  396.90   5.33
# ..    ...    ...    ...   ...     ...  ...    ...      ...     ...    ...
# 501   0.0  0.573  6.593  69.1  2.4786  1.0  273.0     21.0  391.99   9.67
# 502   0.0  0.573  6.120  76.7  2.2875  1.0  273.0     21.0  396.90   9.08
# 503   0.0  0.573  6.976  91.0  2.1675  1.0  273.0     21.0  396.90   5.64
# 504   0.0  0.573  6.794  89.3  2.3889  1.0  273.0     21.0  393.45   6.48
# 505   0.0  0.573  6.030  80.8  2.5050  1.0  273.0     21.0  396.90   7.88
#
#      MEDV
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 18 columns]

# %%
import math
import pandas as pd
import tensorflow as tf
import keras_tuner as kt
import matplotlib.pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras import Sequential
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import MeanSquaredLogarithmicError
from sklearn.model_selection import train_test_split

# %%
from keras.layers import Input,Dense
from keras.models import Model

# number of neurons in the encoding hidden layer
encoding_dim = 2
# input placeholder
input_data = Input(shape=(18,)) # 6 is the number of features/columns
# encoder is the encoded representation of the input
encoded = Dense(encoding_dim, activation ='relu')(input_data)
# decoder is the lossy reconstruction of the input
decoded = Dense(18, activation ='sigmoid')(encoded) # 6 again number of features and should match input_data


# this model maps an input to its reconstruction
autoencoder = Model(input_data, decoded)

# this model maps an input to its encoded representation
encoder = Model(input_data, encoded)
# model optimizer and loss
autoencoder = Model(input_data, decoded)

# loss function and optimizer
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# train test split
from sklearn.model_selection import train_test_split
x_train, x_test, = train_test_split(boston, test_size=0.1, random_state=42)


# train the model
autoencoder.fit(x_train,
                x_train,
                epochs=50,
                batch_size=256,
                shuffle=True)

autoencoder.summary()

# predict after training
# note that we take them from the *test* set
encoded_data = encoder.predict(boston)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 0s 0s/step - loss: 825.0901
# Epoch 2/50
# 2/2 [==============================] - 0s 2ms/step - loss: 824.9999
# Epoch 3/50
# 2/2 [==============================] - 0s 129us/step - loss: 824.9081
# Epoch 4/50
# 2/2 [==============================] - 0s 3ms/step - loss: 824.8154
# Epoch 5/50
# 2/2 [==============================] - 0s 2ms/step - loss: 824.7217
# Epoch 6/50
# 2/2 [==============================] - 0s 2ms/step - loss: 824.6279
# Epoch 7/50
# 2/2 [==============================] - 0s 2ms/step - loss: 824.5335
# Epoch 8/50
# 2/2 [==============================] - 0s 2ms/step - loss: 824.4384
# Epoch 9/50
# 2/2 [==============================] - 0s 2ms/step - loss: 824.3430
# Epoch 10/50
# 2/2 [==============================] - 0s 0s/step - loss: 824.2486
# Epoch 11/50
# 2/2 [==============================] - 0s 7ms/step - loss: 824.1533
# Epoch 12/50
# 2/2 [==============================] - 0s 0s/step - loss: 824.0573
# Epoch 13/50
# 2/2 [==============================] - 0s 0s/step - loss: 823.9612
# Epoch 14/50
# 2/2 [==============================] - 0s 2ms/step - loss: 823.8652
# Epoch 15/50
# 2/2 [==============================] - 0s 2ms/step - loss: 823.7692
# Epoch 16/50
# 2/2 [==============================] - 0s 0s/step - loss: 823.6729
# Epoch 17/50
# 2/2 [==============================] - 0s 2ms/step - loss: 823.5760
# Epoch 18/50
# 2/2 [==============================] - 0s 4ms/step - loss: 823.4785
# Epoch 19/50
# 2/2 [==============================] - 0s 2ms/step - loss: 823.3807
# Epoch 20/50
# 2/2 [==============================] - 0s 2ms/step - loss: 823.2830
# Epoch 21/50
# 2/2 [==============================] - 0s 4ms/step - loss: 823.1859
# Epoch 22/50
# 2/2 [==============================] - 0s 2ms/step - loss: 823.0883
# Epoch 23/50
# 2/2 [==============================] - 0s 2ms/step - loss: 822.9907
# Epoch 24/50
# 2/2 [==============================] - 0s 2ms/step - loss: 822.8927
# Epoch 25/50
# 2/2 [==============================] - 0s 0s/step - loss: 822.7939
# Epoch 26/50
# 2/2 [==============================] - 0s 2ms/step - loss: 822.6953
# Epoch 27/50
# 2/2 [==============================] - 0s 2ms/step - loss: 822.5969
# Epoch 28/50
# 2/2 [==============================] - 0s 2ms/step - loss: 822.4982
# Epoch 29/50
# 2/2 [==============================] - 0s 1ms/step - loss: 822.3992
# Epoch 30/50
# 2/2 [==============================] - 0s 5ms/step - loss: 822.3007
# Epoch 31/50
# 2/2 [==============================] - 0s 889us/step - loss: 822.2022
# Epoch 32/50
# 2/2 [==============================] - 0s 3ms/step - loss: 822.1040
# Epoch 33/50
# 2/2 [==============================] - 0s 4ms/step - loss: 822.0051
# Epoch 34/50
# 2/2 [==============================] - 0s 704us/step - loss: 821.9052
# Epoch 35/50
# 2/2 [==============================] - 0s 2ms/step - loss: 821.8050
# Epoch 36/50
# 2/2 [==============================] - 0s 3ms/step - loss: 821.7050
# Epoch 37/50
# 2/2 [==============================] - 0s 2ms/step - loss: 821.6048
# Epoch 38/50
# 2/2 [==============================] - 0s 2ms/step - loss: 821.5045
# Epoch 39/50
# 2/2 [==============================] - 0s 2ms/step - loss: 821.4039
# Epoch 40/50
# 2/2 [==============================] - 0s 2ms/step - loss: 821.3031
# Epoch 41/50
# 2/2 [==============================] - 0s 2ms/step - loss: 821.2029
# Epoch 42/50
# 2/2 [==============================] - 0s 1ms/step - loss: 821.1023
# Epoch 43/50
# 2/2 [==============================] - 0s 2ms/step - loss: 821.0009
# Epoch 44/50
# 2/2 [==============================] - 0s 1ms/step - loss: 820.8998
# Epoch 45/50
# 2/2 [==============================] - 0s 6ms/step - loss: 820.7983
# Epoch 46/50
# 2/2 [==============================] - 0s 3ms/step - loss: 820.6963
# Epoch 47/50
# 2/2 [==============================] - 0s 2ms/step - loss: 820.5942
# Epoch 48/50
# 2/2 [==============================] - 0s 1ms/step - loss: 820.4921
# Epoch 49/50
# 2/2 [==============================] - 0s 2ms/step - loss: 820.3903
# Epoch 50/50
# 2/2 [==============================] - 0s 807us/step - loss: 820.2878
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 18)]              0
#
#  dense (Dense)               (None, 2)                 38
#
#  dense_1 (Dense)             (None, 18)                54
#
# =================================================================
# Total params: 92
# Trainable params: 92
# Non-trainable params: 0
# _________________________________________________________________

# %%
reduced_df = pd.DataFrame(encoded_data)
reduced_df = reduced_df.add_prefix('feature_')
print(reduced_df.iloc[:, 0])
# Out:
# 0       0.000000
# 1      16.845816
# 2       5.576407
# 3      32.332863
# 4      36.593407
#          ...
# 501     0.000000
# 502     0.000000
# 503     0.000000
# 504     0.000000
# 505     0.000000
# Name: feature_0, Length: 506, dtype: float32

# %%
boston.insert(loc=0, column="ef5", value=reduced_df.iloc[:, 0])

# %%
from sklearn.model_selection import train_test_split

X = boston.iloc[:, :-1]
Y = boston.iloc[:, -1]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (404, 18)
# (102, 18)
# (404,)
# (102,)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

def accuracy_metrics(y_test, predictions):
  a = mean_absolute_error(y_test, predictions)
  b = mean_squared_error(y_test, predictions)
  c = r2_score(y_test, predictions)
  d = np.sqrt(b)
  print("Mean Absolute Error : ",a,"\nMean Square Error : ",b, " \nR2 Score : ",c,"\nRoot Mean Square Error: ",d )

# %%
import pickle

# %%
#DECISION TREE 
from numpy import mean
from numpy import std
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import VotingRegressor
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# get a voting ensemble of models
def get_ensemble():
	# define the base models
	models = list()
	# normalization
	norm = Pipeline([('s', MinMaxScaler()), ('m', DecisionTreeRegressor())])
	models.append(('norm', norm))
	# standardization
	std = Pipeline([('s', StandardScaler()), ('m', DecisionTreeRegressor())])
	models.append(('std', std))
	# robust
	robust = Pipeline([('s', RobustScaler()), ('m', DecisionTreeRegressor())])
	models.append(('robust', robust))
	# power
	power = Pipeline([('s', PowerTransformer()), ('m', DecisionTreeRegressor())])
	models.append(('power', power))
	# quantile
	quant = Pipeline([('s', QuantileTransformer(n_quantiles=100, output_distribution='normal')), ('m', DecisionTreeRegressor())])
	models.append(('quant', quant))
	# kbins
	kbins = Pipeline([('s', KBinsDiscretizer(n_bins=20, encode='ordinal')), ('m', DecisionTreeRegressor())])
	models.append(('kbins', kbins))
	# define the voting ensemble
	ensemble = VotingRegressor(estimators=models)
	# return a list of tuples each with a name and model
	return models + [('ensemble', ensemble)]


models = get_ensemble()

results = list()
for name,model in models:
  model.fit(X_train, Y_train)
  y_preds = model.predict(X_test)
  print('>%s: ' % (name))
  print(accuracy_metrics(Y_test, y_preds))
  print("\n\n")

f = open("DecisionTree", "wb")
pickle.dump(models, f)
# Out:
# >norm:
# Mean Absolute Error :  3.0950980392156855
# Mean Square Error :  31.55696078431372
# R2 Score :  0.5969421193953257
# Root Mean Square Error:  5.6175582582038
# None
#
#
#
# >std:
# Mean Absolute Error :  3.001960784313726
# Mean Square Error :  30.995294117647063
# R2 Score :  0.6041159463623855
# Root Mean Square Error:  5.567341746080176
# None
#
#
#
# >robust:
# Mean Absolute Error :  3.1823529411764704
# Mean Square Error :  32.28392156862744
# R2 Score :  0.587657091124991
# Root Mean Square Error:  5.681894188439929
# None
#
#
#
# >power:
# Mean Absolute Error :  3.2392156862745094
# Mean Square Error :  32.99882352941176
# R2 Score :  0.5785260828785604
# Root Mean Square Error:  5.744460247004218
# None
#
#
#
# >quant:
# Mean Absolute Error :  3.0176470588235302
# Mean Square Error :  29.94098039215686
# R2 Score :  0.6175820547938329
# Root Mean Square Error:  5.471835194169947
# None
#
#
#
# >kbins:
# Mean Absolute Error :  3.150980392156863
# Mean Square Error :  29.41176470588236
# R2 Score :  0.6243414051111986
# Root Mean Square Error:  5.423261445466405
# None
#
#
#
# >ensemble:
# Mean Absolute Error :  2.9279411764705876
# Mean Square Error :  28.93181100217865
# R2 Score :  0.630471562065329
# Root Mean Square Error:  5.3788298915450605
# None
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 6 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 7 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 8 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 11 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 13 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 14 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 15 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 16 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 6 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 7 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 8 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 11 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 13 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 14 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 15 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 16 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '

# %%
#RANDOM FOREST
from sklearn.ensemble import RandomForestRegressor

# get a voting ensemble of models
def get_ensemble():
	# define the base models
	models = list()
	# normalization
	norm = Pipeline([('s', MinMaxScaler()), ('m', RandomForestRegressor(n_estimators = 100, random_state = 0))])
	models.append(('norm', norm))
	# standardization
	std = Pipeline([('s', StandardScaler()), ('m', RandomForestRegressor(n_estimators = 100, random_state = 0))])
	models.append(('std', std))
	# robust
	robust = Pipeline([('s', RobustScaler()), ('m', RandomForestRegressor(n_estimators = 100, random_state = 0))])
	models.append(('robust', robust))
	# power
	power = Pipeline([('s', PowerTransformer()), ('m', RandomForestRegressor(n_estimators = 100, random_state = 0))])
	models.append(('power', power))
	# quantile
	quant = Pipeline([('s', QuantileTransformer(n_quantiles=100, output_distribution='normal')), ('m', RandomForestRegressor(n_estimators = 100, random_state = 0))])
	models.append(('quant', quant))
	# kbins
	kbins = Pipeline([('s', KBinsDiscretizer(n_bins=20, encode='ordinal')), ('m', RandomForestRegressor(n_estimators = 100, random_state = 0))])
	models.append(('kbins', kbins))
	# define the voting ensemble
	ensemble = VotingRegressor(estimators=models)
	# return a list of tuples each with a name and model
	return models + [('ensemble', ensemble)]


models = get_ensemble()

results = list()
for name,model in models:
  model.fit(X_train, Y_train)
  y_preds = model.predict(X_test)
  print('>%s: ' % (name))
  print(accuracy_metrics(Y_test, y_preds))
  print("\n\n")

f = open("RandomForest", "wb")
pickle.dump(models, f)
# Out:
# >norm:
# Mean Absolute Error :  2.1762254901960785
# Mean Square Error :  11.082313833333325
# R2 Score :  0.8584523409466114
# Root Mean Square Error:  3.329010939203013
# None
#
#
#
# >std:
# Mean Absolute Error :  2.1777647058823533
# Mean Square Error :  11.09404090196078
# R2 Score :  0.8583025582264378
# Root Mean Square Error:  3.3307718177564762
# None
#
#
#
# >robust:
# Mean Absolute Error :  2.1806176470588237
# Mean Square Error :  11.097325852941172
# R2 Score :  0.8582606015440724
# Root Mean Square Error:  3.331264902847141
# None
#
#
#
# >power:
# Mean Absolute Error :  2.1744509803921566
# Mean Square Error :  11.135751705882345
# R2 Score :  0.8577698114786806
# Root Mean Square Error:  3.3370273756567155
# None
#
#
#
# >quant:
# Mean Absolute Error :  2.129382352941176
# Mean Square Error :  9.869377264705868
# R2 Score :  0.8739444425466458
# Root Mean Square Error:  3.1415565035036166
# None
#
#
#
# >kbins:
# Mean Absolute Error :  2.3137254901960773
# Mean Square Error :  18.143421823529394
# R2 Score :  0.7682651001441365
# Root Mean Square Error:  4.25950957547103
# None
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 6 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 7 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 8 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 11 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 13 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 14 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 15 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 16 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 6 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 7 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 8 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 11 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 13 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 14 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 15 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 16 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# >ensemble:
# Mean Absolute Error :  2.179766339869281
# Mean Square Error :  11.638659925108929
# R2 Score :  0.8513464704489292
# Root Mean Square Error:  3.411548024740225
# None

# %%
#XGBoost
from xgboost import XGBRegressor

# get a voting ensemble of models
def get_ensemble():
	# define the base models
	models = list()
	# normalization
	norm = Pipeline([('s', MinMaxScaler()), ('m', XGBRegressor())])
	models.append(('norm', norm))
	# standardization
	std = Pipeline([('s', StandardScaler()), ('m', XGBRegressor())])
	models.append(('std', std))
	# robust
	robust = Pipeline([('s', RobustScaler()), ('m', XGBRegressor())])
	models.append(('robust', robust))
	# power
	power = Pipeline([('s', PowerTransformer()), ('m', XGBRegressor())])
	models.append(('power', power))
	# quantile
	quant = Pipeline([('s', QuantileTransformer(n_quantiles=100, output_distribution='normal')), ('m', XGBRegressor())])
	models.append(('quant', quant))
	# kbins
	kbins = Pipeline([('s', KBinsDiscretizer(n_bins=20, encode='ordinal')), ('m', XGBRegressor())])
	models.append(('kbins', kbins))
	# define the voting ensemble
	ensemble = VotingRegressor(estimators=models)
	# return a list of tuples each with a name and model
	return models + [('ensemble', ensemble)]


models = get_ensemble()

results = list()
for name,model in models:
  model.fit(X_train, Y_train)
  y_preds = model.predict(X_test)
  print('>%s: ' % (name))
  print(accuracy_metrics(Y_test, y_preds))
  print("\n\n")

f = open("XGBoost", "wb")
pickle.dump(models, f)
# Out:
# >norm:
# Mean Absolute Error :  2.0174484879362815
# Mean Square Error :  8.285622418264946
# R2 Score :  0.8941727806355648
# Root Mean Square Error:  2.878475710904114
# None
#
#
#
# >std:
# Mean Absolute Error :  2.0160811340107636
# Mean Square Error :  8.28630567259469
# R2 Score :  0.8941640538432751
# Root Mean Square Error:  2.878594391816028
# None
#
#
#
# >robust:
# Mean Absolute Error :  2.0179900908002666
# Mean Square Error :  8.294866248231735
# R2 Score :  0.8940547148135566
# Root Mean Square Error:  2.8800809447360565
# None
#
#
#
# >power:
# Mean Absolute Error :  2.0215958249335193
# Mean Square Error :  8.30772950334883
# R2 Score :  0.8938904202738951
# Root Mean Square Error:  2.882313220895472
# None
#
#
#
# >quant:
# Mean Absolute Error :  2.0119093287224863
# Mean Square Error :  8.211781647324845
# R2 Score :  0.8951159039242983
# Root Mean Square Error:  2.865620639115521
# None
#
#
#
# >kbins:
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 6 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 7 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 8 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 11 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 13 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 14 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 15 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 16 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# Mean Absolute Error :  2.4260080879809807
# Mean Square Error :  19.907148730161722
# R2 Score :  0.7457380883126921
# Root Mean Square Error:  4.4617427906773965
# None
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 6 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 7 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 8 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 11 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 13 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 14 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 15 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 16 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# >ensemble:
# Mean Absolute Error :  1.9927903474545945
# Mean Square Error :  8.67516951184698
# R2 Score :  0.8891973323657514
# Root Mean Square Error:  2.9453640711883105
# None

# %%
from sklearn.ensemble import AdaBoostRegressor



# get a voting ensemble of models
def get_ensemble():
	# define the base models
	models = list()
	# normalization
	norm = Pipeline([('s', MinMaxScaler()), ('m', AdaBoostRegressor(n_estimators = 100, random_state = 0))])
	models.append(('norm', norm))
	# standardization
	std = Pipeline([('s', StandardScaler()), ('m', AdaBoostRegressor(n_estimators = 100, random_state = 0))])
	models.append(('std', std))
	# robust
	robust = Pipeline([('s', RobustScaler()), ('m', AdaBoostRegressor(n_estimators = 100, random_state = 0))])
	models.append(('robust', robust))
	# power
	power = Pipeline([('s', PowerTransformer()), ('m', AdaBoostRegressor(n_estimators = 100, random_state = 0))])
	models.append(('power', power))
	# quantile
	quant = Pipeline([('s', QuantileTransformer(n_quantiles=100, output_distribution='normal')), ('m',AdaBoostRegressor(n_estimators = 100, random_state = 0))])
	models.append(('quant', quant))
	# kbins
	kbins = Pipeline([('s', KBinsDiscretizer(n_bins=20, encode='ordinal')), ('m', AdaBoostRegressor(n_estimators = 100, random_state = 0))])
	models.append(('kbins', kbins))
	# define the voting ensemble
	ensemble = VotingRegressor(estimators=models)
	# return a list of tuples each with a name and model
	return models + [('ensemble', ensemble)]


models = get_ensemble()

results = list()
for name,model in models:
  model.fit(X_train, Y_train)
  y_preds = model.predict(X_test)
  print('>%s: ' % (name))
  print(accuracy_metrics(Y_test, y_preds))
  print("\n\n")

f = open("AdaBoost", "wb")
pickle.dump(models, f)
# Out:
# >norm:
# Mean Absolute Error :  2.642032672095444
# Mean Square Error :  12.104073323386844
# R2 Score :  0.8454020279787862
# Root Mean Square Error:  3.4790908759885597
# None
#
#
#
# >std:
# Mean Absolute Error :  2.639447766001332
# Mean Square Error :  12.214341985203028
# R2 Score :  0.8439936333798095
# Root Mean Square Error:  3.494902285501417
# None
#
#
#
# >robust:
# Mean Absolute Error :  2.644150458149448
# Mean Square Error :  12.076443919691517
# R2 Score :  0.8457549215597594
# Root Mean Square Error:  3.4751178281738184
# None
#
#
#
# >power:
# Mean Absolute Error :  2.622293195959421
# Mean Square Error :  11.682967544018597
# R2 Score :  0.8507805561616051
# Root Mean Square Error:  3.4180356264993197
# None
#
#
#
# >quant:
# Mean Absolute Error :  2.646258993351612
# Mean Square Error :  12.507760627710764
# R2 Score :  0.8402459753912159
# Root Mean Square Error:  3.5366312541330576
# None
#
#
#
# >kbins:
# Mean Absolute Error :  2.737468858574225
# Mean Square Error :  21.524222963491237
# R2 Score :  0.7250841819456947
# Root Mean Square Error:  4.639420541780109
# None
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 6 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 7 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 8 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 11 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 13 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 14 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 15 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 16 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# >ensemble:
# Mean Absolute Error :  2.617583658165678
# Mean Square Error :  11.85085343272559
# R2 Score :  0.848636251741792
# Root Mean Square Error:  3.442506852967121
# None
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 6 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 7 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 8 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 11 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 13 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 14 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 15 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 16 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '

# %%
from sklearn.svm import SVR

# %%
# get a voting ensemble of models
def get_ensemble():
	# define the base models
	models = list()
	# normalization
	norm = Pipeline([('s', MinMaxScaler()), ('m', SVR())])
	models.append(('norm', norm))
	# standardization
	std = Pipeline([('s', StandardScaler()), ('m', SVR())])
	models.append(('std', std))
	# robust
	robust = Pipeline([('s', RobustScaler()), ('m', SVR())])
	models.append(('robust', robust))
	# power
	power = Pipeline([('s', PowerTransformer()), ('m', SVR())])
	models.append(('power', power))
	# quantile
	quant = Pipeline([('s', QuantileTransformer(n_quantiles=100, output_distribution='normal')), ('m',SVR())])
	models.append(('quant', quant))
	# kbins
	kbins = Pipeline([('s', KBinsDiscretizer(n_bins=20, encode='ordinal')), ('m', SVR())])
	models.append(('kbins', kbins))
	# define the voting ensemble
	ensemble = VotingRegressor(estimators=models)
	# return a list of tuples each with a name and model
	return models + [('ensemble', ensemble)]


models = get_ensemble()

results = list()
for name,model in models:
  model.fit(X_train, Y_train)
  y_preds = model.predict(X_test)
  print('>%s: ' % (name))
  print(accuracy_metrics(Y_test, y_preds))
  print("\n\n")

f = open("SVR", "wb")
pickle.dump(models, f)
# Out:
# >norm:
# Mean Absolute Error :  3.384177996623671
# Mean Square Error :  29.85911249281681
# R2 Score :  0.6186277037149406
# Root Mean Square Error:  5.46434922866546
# None
#
#
#
# >std:
# Mean Absolute Error :  3.027325315507504
# Mean Square Error :  24.338613235349225
# R2 Score :  0.6891376855158686
# Root Mean Square Error:  4.9334180073605385
# None
#
#
#
# >robust:
# Mean Absolute Error :  4.480797004235522
# Mean Square Error :  51.79916379026838
# R2 Score :  0.3384007630805186
# Root Mean Square Error:  7.197163593407363
# None
#
#
#
# >power:
# Mean Absolute Error :  2.984669539443311
# Mean Square Error :  23.80778945817946
# R2 Score :  0.6959175750008841
# Root Mean Square Error:  4.879322643377814
# None
#
#
#
# >quant:
# Mean Absolute Error :  3.9205138808371873
# Mean Square Error :  38.70444479430318
# R2 Score :  0.5056516501891101
# Root Mean Square Error:  6.221289640766067
# None
#
#
#
# >kbins:
# Mean Absolute Error :  3.049374918816839
# Mean Square Error :  23.33064957237763
# R2 Score :  0.7020117927691185
# Root Mean Square Error:  4.8301811117573665
# None
#
#
#
# >ensemble:
# Mean Absolute Error :  3.3177618560743976
# Mean Square Error :  29.853524176034814
# R2 Score :  0.6186990798887646
# Root Mean Square Error:  5.463837861433556
# None
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 6 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 7 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 8 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 11 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 13 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 14 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 15 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 16 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 6 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 7 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 8 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 11 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 13 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 14 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 15 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '
# C:\Users\eswar\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:220: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 16 are removed. Consider decreasing the number of bins.
#   warnings.warn('Bins whose width are too small (i.e., <= '

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn import svm



regressions = [DecisionTreeRegressor(), 
               RandomForestRegressor(n_estimators = 100, random_state = 0),
               XGBRegressor(),
               AdaBoostRegressor(n_estimators = 100, random_state = 0),
               svm.SVR()]

for r in regressions:
  r.fit(X_train, Y_train)
  ypred = r.predict(X_test)
  accuracy_metrics(ypred, Y_test)
  print("\n\n")
# Out:
# Mean Absolute Error :  3.21764705882353
# Mean Square Error :  33.15274509803921
# R2 Score :  0.6427169648885452
# Root Mean Square Error:  5.757842052196223
#
#
#
# Mean Absolute Error :  2.180421568627451
# Mean Square Error :  11.113779892156858
# R2 Score :  0.8445007199424854
# Root Mean Square Error:  3.333733626455008
#
#
#
# Mean Absolute Error :  2.015996855380488
# Mean Square Error :  8.285561969012221
# R2 Score :  0.8877154611618495
# Root Mean Square Error:  2.878465210665611
#
#
#
# Mean Absolute Error :  2.6548836393770086
# Mean Square Error :  12.407386345394084
# R2 Score :  0.7927277451274164
# Root Mean Square Error:  3.522412006763843
#
#
#
# Mean Absolute Error :  5.056763324472352
# Mean Square Error :  58.031375857370804
# R2 Score :  -3.1650629297671733
# Root Mean Square Error:  7.617832753307912
